# %%
from plot_changepoint import plot_changepoint

cenario = "NDT/rtt_down"
metric = "NDT/rtt_down"
method = ["cusum", "pelt", "vwcd"]
lista_arquivos = ["Land_RNP-RJ_s03.csv"]

plot_changepoint(cenario, method, file=lista_arquivos[0], threshold=0.95, tail_plot=True, show = True, metric=metric)
slice_window = ["2026-01-01","2026-01-06"]
plot_changepoint(cenario, method, file=lista_arquivos[0], slice_window=slice_window, threshold=0.95, tail_plot=True, show = True, metric=metric)
# slice_window = ["2026-01-12","2026-01-13"]
# plot_changepoint(cenario, method, file=lista_arquivos[0], slice_window=slice_window, threshold=0.95, tail_plot=True, show = True, metric=metric)
# slice_window = ["2026-01-29","2026-01-30"]
# plot_changepoint(cenario, method, file=lista_arquivos[0], slice_window=slice_window, threshold=0.95, tail_plot=True, show = True, metric=metric)
# slice_window = ["2026-02-02","2026-02-03"]
# plot_changepoint(cenario, method, file=lista_arquivos[0], slice_window=slice_window, threshold=0.95, tail_plot=True, show = True, metric=metric)
# slice_window = ["2026-02-03","2026-02-04"]
# plot_changepoint(cenario, method, file=lista_arquivos[0], slice_window=slice_window, threshold=0.95, tail_plot=True, show = True, metric=metric)

# %%
cenario = "NDT/rtt_down"
metric = "NDT/tp_up"
method = ["cusum", "pelt", "vwcd"]
lista_arquivos = ["Theo_RNP-ES_s01.csv"]

plot_changepoint(cenario, method, file=lista_arquivos[0], threshold=0.95, tail_plot=True, show = True, metric=metric)
slice_window = ["2026-01-12","2026-01-14"]
plot_changepoint(cenario, method, file=lista_arquivos[0], slice_window=slice_window, threshold=0.95, show = True,tail_plot=True, metric=metric)

# %%
cenario = "NDT/rtt_down"
metric = "NDT/tp_up"
method = ["cusum", "pelt", "vwcd"]
lista_arquivos = ["Theo_RNP-RJ_s04.csv"]

plot_changepoint(cenario, method, file=lista_arquivos[0], threshold=0.95, tail_plot=True, show = True, metric=metric)
slice_window = ["2026-02-11","2026-02-12"]
plot_changepoint(cenario, method, file=lista_arquivos[0], slice_window=slice_window, threshold=0.95,tail_plot=True, show = True, metric=metric)

# %%
# # selecionar 5 arquivos aleatórios na pasta series/cenario/full
# import os
# import random
# pasta = f"series/{cenario}"
# arquivos = [f for f in os.listdir(pasta) if f.endswith(".csv")]
# arquivos_selecionados = random.sample(arquivos, 1)
# for file in arquivos_selecionados:
#     print(file)
#     plot_changepoint(cenario, method, file=file, threshold=0.95, tail_plot=True, show = True)

# %%
# import os
# import matplotlib.pyplot as plt
# from unittest.mock import patch

# def salvar_antes_de_fechar(*args, **kwargs):
#     fig = plt.gcf()
#     if fig.get_axes():
#         caminho_completo = os.path.join(pasta_destino, nome_arquivo_saida)
#         fig.savefig(caminho_completo)
#     original_close(*args, **kwargs)

# pasta_destino = "next_presentation/compare"
# os.makedirs(pasta_destino, exist_ok=True)

# for idx, file in enumerate(arquivos_selecionados):

#     nome_arquivo_saida = f"serie{idx+1}.png"

#     original_close = plt.close

#     with patch('matplotlib.pyplot.close', side_effect=salvar_antes_de_fechar):
#         plot_changepoint(
#             cenario=cenario, 
#             methods=method, 
#             file=file, 
#             tail_plot=True
#         )
