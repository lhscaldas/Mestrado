# %%
from DISPLAY import plot_feature_with_means

# %%
INPUT_DIR = 'changepoints/logaritmica_KS_recalc/'
CLIENT = 'Curi'
SITE = 'gru02'
VARIABLES = ['throughput_download', 'throughput_upload', 'rtt_download', 'rtt_upload', 'packet_loss']

for variable in VARIABLES:
    plot_feature_with_means(
        input_dir=INPUT_DIR,
        client=CLIENT,
        site=SITE,
        variable=variable
    )
