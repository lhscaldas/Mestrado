# %%
import pandas as pd
file_path = 'segments/NDT/vwcd_rtt_down_0.95.csv'
df = pd.read_csv(file_path)

# %%
print(df.columns)
# Out:
# Index(['client', 'server', 'block', 'segment_number', 'final_timestamp',
#        'start_timestamp', 'metrics_at_threshold', 'n_points', 'rtt_down_mean',
#        'rtt_down_median', 'rtt_down_std', 'tp_down_mean', 'tp_down_median',
#        'tp_down_std', 'rtt_up_mean', 'rtt_up_median', 'rtt_up_std',
#        'tp_up_mean', 'tp_up_median', 'tp_up_std', 'pl_mean', 'pl_median',
#        'pl_std'],
#       dtype='object')

# %%
# printar, para cliente server e block especificos, os timestamps dos segmentos detectados e a mediana da metrica escolhida nesses segmentos
client = 'Theo'
server = 'RNP-RJ'
block = 's04'
metrica = 'tp_up_median'
df_filtered = df[(df['client'] == client) & (df['server'] == server) & (df['block'] == block)]
print(df_filtered[['start_timestamp', 'final_timestamp', metrica]])
# Out:
#           start_timestamp      final_timestamp  tp_up_median
# 1544  2025-12-29 16:37:46  2026-02-10 12:50:54    302.989568
# 1545  2026-02-10 13:31:32  2026-02-10 15:28:54    281.445045
# 1546  2026-02-10 16:35:47  2026-02-11 11:31:23    300.224731
# 1547  2026-02-11 11:42:47  2026-02-11 13:48:55      0.820643
# 1548  2026-02-11 14:57:22  2026-02-11 21:57:08    279.470821
# 1549  2026-02-11 22:24:54  2026-02-21 01:01:43    300.503874

# %%
(279.470821-0.820643)/0.820643
# Out:
# 339.5510325439929
